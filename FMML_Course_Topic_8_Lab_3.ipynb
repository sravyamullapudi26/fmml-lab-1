# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyamullapudi26/fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 03:42:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  58.3MB/s    in 1.2s
#
# 2024-04-02 03:42:36 (58.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 27957  1705.01781v2  In this paper we introduce the problem of pred...    cs
# 21571   1103.0431v2  We investigate the learning rate of multiple k...  stat
# 17048  1708.01759v1  Traditional automatic evaluation measures for ...    cs
# 23019  1802.01334v1  Extracting information from functional magneti...  stat
# 14761   1204.0191v1  With the advent of digital optical scanners, a...    cs
# ...             ...                                                ...   ...
# 6186   1609.02200v2  Probabilistic models with discrete latent vari...  stat
# 10441   1101.1057v3  We consider the problem of online linear regre...  stat
# 3478   1708.03218v1  The Nystr\"om method is a popular technique fo...  stat
# 8055    1110.0061v1  The use of image transformations is essential ...    cs
# 3762   1707.06633v3  As autonomous service robots become more affor...    cs
#
#                                                    title  year  \
# 27957    Am I Done? Predicting Action Progress in Videos  2017
# 21571  Fast Convergence Rate of Multiple Kernel Learn...  2011
# 17048  Referenceless Quality Estimation for Natural L...  2017
# 23019  Information Assisted Dictionary Learning for f...  2018
# 14761  OCR Post-Processing Error Correction Algorithm...  2012
# ...                                                  ...   ...
# 6186                   Discrete Variational Autoencoders  2016
# 10441  Sparsity regret bounds for individual sequence...  2011
# 3478   Improved Fixed-Rank Nyström Approximation via ...  2017
# 8055   Learning image transformations without trainin...  2011
# 3762   Acting Thoughts: Towards a Mobile Robotic Serv...  2017
#
#                                                 keywords
# 27957  [introduce, predicting, extremely, important, ...
# 21571  [investigate, regularization, regularizer, reg...
# 17048  [traditional, automatic, evaluation, generatio...
# 23019  [extracting, information, functional, resonanc...
# 14761  [textbooks, magazines, documents, transformed,...
# ...                                                  ...
# 6186   [probabilistic, variables, naturally, difficul...
# 10441  [regression, arbitrary, deterministic, sequenc...
# 3478   [technique, computing, approximations, approxi...
# 8055   [transformations, essential, efficient, transf...
# 3762   [autonomous, affordable, available, interfaces...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 27957    [introduce, predicting, extremely, important, ...
# 21571    [investigate, regularization, regularizer, reg...
# 17048    [traditional, automatic, evaluation, generatio...
# 23019    [extracting, information, functional, resonanc...
# 14761    [textbooks, magazines, documents, transformed,...
#                                ...
# 38188    [comparison, linguistic, literature, linguisti...
# 22616    [supervised, distributionally, optimization, t...
# 9527     [microscopic, pedestrian, trajectory, pedestri...
# 18113    [performance, generation, wisconsin, generates...
# 35794    [knowledge, compilation, augmenting, decomposi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8695 words.
# Out of those 4557 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a1dbb7bf-66c6-4dcb-829d-5af8fed0ca51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1dbb7bf-66c6-4dcb-829d-5af8fed0ca51")) {                    Plotly.newPlot(                        "a1dbb7bf-66c6-4dcb-829d-5af8fed0ca51",                        [{"x":["evaluation","capability","introduce","convolutional","motivated","effectively","demonstrate","predicting","detection","execution","combination","extremely","framework","protocols","facilitates","framewise","applications","additionally","exploiting","important","interaction","recurrent","localization","predictions","introducing","regularization","controlling","investigate","regularizer","convergence","relatively","components","smoothness","automatic","generation","comparing","references","outperforms","synthetic","comparable","representation","traditional","challenging","estimation","correlation","constraints","resonance","information","techniques","functional","available","extracting","performance","improvement","dictionary","demanding","incorporating","regarding","experiments","identifies","character","recognizes","translate","transformed","developed","linguistics","correction","convenient","containing","suggestion","platforms","recognition","processing","correcting","detecting","collection","textbooks","parallelized","algorithm","sequences","manipulated","occasionally","unfortunately","documents","harnesses","misspellings","significant","graphical","electronic","imperfect","interactions","expression","dimensional","considering","predictor","simulated","classification","considered","measurements","situations","microarray","predictable","converged","variables","application","computational","compression","procedure","modelling","prediction","thousands","selection","challenges","compressing","compressed","regression","exponentially","parameters","materials","consuming","numerical","versatility","artificial","contribution","approximation","nonlinear","exhaustive","approximating","appropriate","mechanical","development","relationship","advantages","particular","experimental","accelerate","simulations","quantification","complexity","nontrivial","computationally","therefore","quantifying","approaches","calibration","computers","strategies","calibrated","engineers","efficient","represent","increases","relationships","implementation","technique","drawbacks","potential","demonstrated","structures","instantiated","hierarchy","concurrent","evaluated","assumptions","partially","variational","scalability","vectorization","magnitude","automatically","dynamically","presented","determined","hierarchical","empirical","communication","algorithms","distributed","structure","collapsed","nonparametric","sacrifice","initialization","restaurant","allocation","dirichlet","inference","intuition","underlying","background","encouraging","multimodality","regularize","partition","classifiers","effectiveness","desirable","subsequently","influential","intuitive"],"y":[235,57,319,384,68,123,594,80,367,26,130,50,595,12,20,2,382,66,68,359,98,132,76,83,49,94,17,132,22,115,71,112,14,198,146,74,7,247,129,96,379,188,303,208,80,144,20,703,376,36,300,81,873,157,50,7,51,42,586,21,55,4,22,23,195,10,15,12,61,1,28,347,304,10,73,58,1,6,848,102,4,2,30,63,4,3,240,65,18,6,84,39,166,60,13,78,481,126,66,51,4,5,3,115,232,307,32,118,58,224,26,171,103,8,21,127,16,227,10,36,81,6,127,77,122,53,16,14,86,14,137,89,98,275,413,15,42,12,216,13,94,154,9,433,19,17,98,9,6,398,133,58,72,144,245,20,162,97,129,6,38,9,149,63,44,53,27,2,62,181,35,179,30,106,133,52,607,93,331,3,14,2,24,7,21,22,224,18,131,81,20,3,11,29,115,204,24,33,9,39],"type":"bar"},{"x":["evaluation","capability","introduce","convolutional","motivated","effectively ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4557,), (4557, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8041666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.391304347826087);'>Spatiotemporal</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Articulated</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>Dynamic</span> <span style=''>SLAM</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.391304347826087);'>spatiotemporal</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>articulation</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>articulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>a</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>model</span> <span style=''>solely</span> <span style=''>using</span> <span style=''>passive</span> <span style='background-color:rgba(255, 0, 0, 0.39055793991416304);'>observations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>model</span> <span style=''>can</span> <span style=''>predict</span> <span style=''>future</span> <span style=''>mo</span> <span style=''>tions</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>articulated</span> <span style=''>object</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>because</span> <span style=''>of</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>and</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923077);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.49514563106796117);'>predictive</span> <span style=''>model</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporating</span> <span style=''>it</span> <span style=''>within</span> <span style=''>a</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneous</span> <span style='background-color:rgba(0, 255, 0, 0.7674418604651163);'>localization</span> <span style=''>and</span> <span style=''>mapping</span> <span style=''>(SLAM)</span> <span style=''>pipeline</span> <span style=''>for</span> <span style=''>mapping</span> <span style=''>and</span> <span style=''>robot</span> <span style='background-color:rgba(0, 255, 0, 0.7674418604651163);'>localization</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unexplored</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.5084745762711864);'>environments</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>localize</span> <span style=''>the</span> <span style=''>robot</span> <span style=''>and</span> <span style=''>map</span> <span style=''>a</span> <span style=''>dynamic</span> <span style=''>scene</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explaining</span> <span style=''>the</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Precision</span> <span style=''>Matrices</span> <br/><br/><span style=''>Given</span> <span style=''>n</span> <span style=''>iid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>a</span> <span style=''>random</span> <span style=''>vector</span> <span style=''>(XZ)</span> <span style=''>where</span> <span style=''>X</span> <span style=''>is</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>vector</span> <span style=''>and</span> <span style=''>Z</span> <span style=''>is</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>index</span> <span style=''>variable</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>Omega(z)</span> <span style=''>(E(X</span> <span style=''>EX</span> <span style=''>mid</span> <span style=''>Z)(X</span> <span style=''>EX</span> <span style=''>mid</span> <span style=''>Z)T</span> <span style=''>mid</span> <span style=''>Zz)</span> <span style=''>1</span> <span style=''>under</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>non</span> <span style=''>zero</span> <span style=''>elements</span> <span style=''>is</span> <span style=''>small</span> <span style=''>and</span> <span style=''>does</span> <span style=''>not</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style=''>index</span> <span style=''>variable</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>ideas</span> <span style=''>of</span> <span style=''>the</span> <span style=''>local</span> <span style=''>constant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style=''>and</span> <span style=''>the</span> <span style=''>group</span> <span style=''>Lasso</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style=''>matrix</span> <span style=''>A</span> <span style=''>proximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>our</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Potential</span> <span style=''>Auto</span> <span style=''>Encoders</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>suggest</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>make</span> <span style=''>use</span> <span style=''>of</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>to</span> <span style=''>train</span> <span style=''>Auto</span> <span style=''>Encoders</span> <span style=''>(AEs)</span> <span style=''>In</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>AEs</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularized</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>between</span> <span style=''>input</span> <span style=''>and</span> <span style=''>encoding</span> <span style='background-color:rgba(255, 0, 0, 0.4191919191919193);'>variables</span> <span style=''>of</span> <span style=''>AEs</span> <span style=''>during</span> <span style=''>the</span> <span style=''>training</span> <span style=''>phase</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>entropy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>encoding</span> <span style='background-color:rgba(255, 0, 0, 0.4191919191919193);'>variables</span> <span style=''>and</span> <span style=''>the</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.43624161073825496);'>parametric</span> <span style=''>method</span> <span style=''>We</span> <span style=''>also</span> <span style=''>give</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style=''>view</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5725806451612904);'>Variational</span> <span style=''>AEs</span> <span style=''>(VAEs)</span> <span style=''>which</span> <span style=''>suggests</span> <span style=''>that</span> <span style=''>VAEs</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.43624161073825496);'>parametric</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>estimate</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.41680960548885077);'>Experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.43624161073825496);'>parametric</span> <span style=''>models</span> <span style=''>have</span> <span style=''>more</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>freedom</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <br/><br/><span style=''>The</span> <span style=''>mixture</span> <span style=''>models</span> <span style=''>have</span> <span style=''>become</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>given</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>in</span> <span style=''>which</span> <span style=''>its</span> <span style=''>based</span> <span style=''>however</span> <span style=''>for</span> <span style=''>modern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>their</span> <span style=''>large</span> <span style=''>size</span> <span style=''>these</span> <span style=''>models</span> <span style=''>behave</span> <span style=''>disappointingly</span> <span style=''>in</span> <span style=''>setting</span> <span style=''>out</span> <span style=''>the</span> <span style=''>model</span> <span style=''>making</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>of</span> <span style=''>relevant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>for</span> <span style=''>this</span> <span style=''>type</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>After</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recalling</span> <span style=''>the</span> <span style=''>basics</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>model</span> <span style=''>this</span> <span style=''>article</span> <span style=''>will</span> <span style=''>examine</span> <span style=''>the</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presenting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>opportunities</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvement</span> <span style=''>of</span> <span style=''>these</span> <span style=''>methods</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10864108999641449)
# 	processing (0.10899964144854786)
# 	representation (0.13589100035855145)
# 	segmentation (0.0720688418788096)
# 	experimental (0.1480817497310864)
# 	information (0.25206167084976694)
# 	recognition (0.12441735389028326)
# 	detection (0.1315883829329509)
# 	different (0.27106489781283616)
# 	convolutional (0.13768375761921836)
#
# Some Statistics words are:
# 	convergence (0.12381899552461462)
# 	estimation (0.1601193436101442)
# 	statistical (0.15365489806066635)
# 	stochastic (0.13823968175037296)
# 	variables (0.13973147687717555)
# 	theoretical (0.15713575335653904)
# 	inference (0.18000994530084535)
# 	distribution (0.18100447538538042)
# 	dimensional (0.18647439085032322)
# 	regression (0.17702635504724018)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b3021219-9388-407d-9cf7-d6534484f145" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3021219-9388-407d-9cf7-d6534484f145")) {                    Plotly.newPlot(                        "b3021219-9388-407d-9cf7-d6534484f145",                        [{"x":["evaluation","capability","introduce","convolutional","motivated","effectively","demonstrate","predicting","detection","execution","combination","extremely","framework","protocols","facilitates","framewise","applications","additionally","exploiting","important","interaction","recurrent","localization","predictions","introducing","regularization","controlling","investigate","regularizer","convergence","relatively","components","smoothness","automatic","generation","comparing","references","outperforms","synthetic","comparable","representation","traditional","challenging","estimation","correlation","constraints","resonance","information","techniques","functional","available","extracting","performance","improvement","dictionary","demanding","incorporating","regarding","experiments","identifies","character","recognizes","translate","transformed","developed","linguistics","correction","convenient","containing","suggestion","platforms","recognition","processing","correcting","detecting","collection","textbooks","parallelized","algorithm","sequences","manipulated","occasionally","unfortunately","documents","harnesses","misspellings","significant","graphical","electronic","imperfect","interactions","expression","dimensional","considering","predictor","simulated","classification","considered","measurements","situations","microarray","predictable","converged","variables","application","computational","compression","procedure","modelling","prediction","thousands","selection","challenges","compressing","compressed","regression","exponentially","parameters","materials","consuming","numerical","versatility","artificial","contribution","approximation","nonlinear","exhaustive","approximating","appropriate","mechanical","development","relationship","advantages","particular","experimental","accelerate","simulations","quantification","complexity","nontrivial","computationally","therefore","quantifying","approaches","calibration","computers","strategies","calibrated","engineers","efficient","represent","increases","relationships","implementation","technique","drawbacks","potential","demonstrated","structures","instantiated","hierarchy","concurrent","evaluated","assumptions","partially","variational","scalability","vectorization","magnitude","automatically","dynamically","presented","determined","hierarchical","empirical","communication","algorithms","distributed","structure","collapsed","nonparametric","sacrifice","initialization","restaurant","allocation","dirichlet","inference","intuition","underlying","background","encouraging","multimodality","regularize","partition","classifiers","effectiveness","desirable","subsequently","influential","intuitive","resultant","transcription","instruments","generalizing","isolation","objective","transcribing","polyphonic","correlates","perception","improving","condition","continuous","environment","investigating","environments","reinforcement","potentially","specification","vocabulary","analyzing","constructed","different","implemented","resources","morphosyntactic","synthesizing","highlighting","sentences","tentative","minimalist","established","preliminary","described","achievement","templates","comfortable","solutions","synthesis","knowledge","sufficient","promising","backpropagation","integration","supervised","regardless","objectness","relations","selecting","predicted","supervision","attentional","demonstrating","labelling","complementing","eff ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	differing
# 	confounders
# 	nontrivially
# 	itinerary
# 	accommodates
# 	procrustes
# 	spectrometry
# 	substantiate
# 	unwrapping
# 	sparsification
# 	physiologic
# 	detectability
# 	appreciate
# 	subpopulations
# 	isometrically
# 	customization
# 	dendrogram
# 	suboptimality
# 	fragility
# 	seasonality
# Some words which never appear in Statistics papers:
# 	framewise
# 	recognizes
# 	misspellings
# 	engineers
# 	multimodality
# 	transcribing
# 	morphosyntactic
# 	tentative
# 	minimalist
# 	comfortable
# 	attentive
# 	operative
# 	diffeomorphic
# 	successor
# 	warehouse
# 	australia
# 	completes
# 	fortunately
# 	photometric
# 	automotive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081949024563134e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
