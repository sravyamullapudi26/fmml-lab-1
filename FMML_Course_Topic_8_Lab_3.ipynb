# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyamullapudi26/fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-13 07:12:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   188MB/s    in 0.4s
#
# 2024-05-13 07:12:59 (188 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6755   1705.10246v3  We consider neural network training, in applic...  stat
# 23366   1111.1752v1  The recent technological progress in acquisiti...    cs
# 39603  1610.01852v1  We propose a new compressive imaging method fo...    cs
# 2851   1802.09030v1  Combinatorial optimization is a common theme i...  stat
# 27536  1703.09856v1  This paper introduces a new approach to automa...    cs
# ...             ...                                                ...   ...
# 4128   1512.04134v1  Microsoft Kinect camera and its skeletal track...    cs
# 25657  1511.01154v1  Multi-modal image registration is a challengin...    cs
# 3954   cs/0611140v1  The local reconstruction of a railway schedule...    cs
# 21993   1310.1867v4  Significant success has been reported recently...  stat
# 29674  1710.01245v1  This paper introduces a new approach to non-lo...    cs
#
#                                                    title  year  \
# 6755                   The Principle of Logit Separation  2017
# 23366                  New Method for 3D Shape Retrieval  2011
# 39603  Compressive Imaging with Iterative Forward Models  2016
# 2851                                   Cakewalk Sampling  2018
# 27536  Automatic Detection of Knee Joints and Quantif...  2017
# ...                                                  ...   ...
# 4128   Evaluation of Pose Tracking Accuracy in the Fi...  2015
# 25657  Robust Registration of Calcium Images by Learn...  2015
# 3954   On the Benefits of Inoculation, an Example in ...  2006
# 21993  Mean Field Bayes Backpropagation: scalable tra...  2013
# 29674  Robust non-local means filter for ultrasound i...  2017
#
#                                                 keywords
# 6755   [applications, different, different, applicati...
# 23366  [technological, acquisition, processing, proli...
# 39603  [compressive, reconstructing, scattered, measu...
# 2851   [combinatorial, optimization, underlies, consi...
# 27536  [introduces, automatically, automatically, qua...
# ...                                                  ...
# 4128   [microsoft, capabilities, researchers, commerc...
# 25657  [registration, challenging, complementary, sub...
# 3954   [reconstruction, following, perturbation, mini...
# 21993  [significant, classification, computationally,...
# 29674  [introduces, denoising, estimating, corrupted,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6755     [applications, different, different, applicati...
# 23366    [technological, acquisition, processing, proli...
# 39603    [compressive, reconstructing, scattered, measu...
# 2851     [combinatorial, optimization, underlies, consi...
# 27536    [introduces, automatically, automatically, qua...
#                                ...
# 822      [inference, recognition, attention, mechanism,...
# 27033    [impressive, performance, plasticity, convolut...
# 22486    [regression, incorporating, saturation, requir...
# 22376    [controlled, interventions, information, parti...
# 6568     [bootstrap, aggregation, replacement, evaluati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8745 words.
# Out of those 4582 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dade64a9-1c27-492f-9795-25a39a61f582" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dade64a9-1c27-492f-9795-25a39a61f582")) {                    Plotly.newPlot(                        "dade64a9-1c27-492f-9795-25a39a61f582",                        [{"x":["optimizing","available","guideline","experiments","classifier","accurately","therefore","separation","performance","functions","classifiers","classification","designing","different","principle","important","tensorflow","improvement","applications","technological","characteristic","similarity","processing","databases","proliferation","hausdorff","necessary","acquisition","evaluated","recognition","introduce","consequently","retrieval","descriptor","techniques","algorithm","simulations","reconstructing","compressive","preferable","accelerated","measurements","numerical","expanding","scattering","optimization","computing","guaranteed","construct","nonlinear","formation","phenomenon","measurement","inaccurate","analytically","scattered","iterative","outperforms","considerable","continuous","estimates","strategies","transforms","expectation","experimental","undirected","probabilities","distribution","structure","providing","benchmark","consistently","underlies","evaluations","combinatorial","converting","approaches","significant","construction","generality","parametric","constructions","objective","algorithms","cumulative","localizing","categorical","producing","multicenter","initiative","regression","osteoarthritis","classifying","naturally","automatic","quantification","simultaneous","detection","automatically","outperform","promising","extremely","introduces","localized","convolutional","quantifying","distinguish","including","practitioners","properties","regularly","resurgence","consistent","multilayer","traditional","applicability","challenges","highlight","anticipate","scientific","established","cheminformatics","reviewing","introductory","respective","computational","materials","transformative","expectations","particularly","chemistry","screening","disparate","prediction","documented","exponential","artificial","literature","measuring","distributional","relatedness","semantics","compositional","evaluating","empirical","combination","precision","embedding","represent","combinational","presented","outstanding","sentiment","embeddings","selecting","organized","penalizing","superiority","representation","importance","searching","beneficial","representations","attributed","efficient","minimization","disorders","dissimilar","progresses","constructing","omnipresent","framework","demonstrate","theoretical","generally","paradigms","described","discovery","continuously","perspective","mathematics","definitions","expressed","shortcomings","intelligence","possibility","interdependencies","manipulated","dependency","programming","essential","introduction","relations","characterise","information","investigate","representable","representatives","equivalence","individual"],"y":[45,296,4,577,151,74,138,27,896,220,113,548,60,724,58,389,5,126,432,8,27,156,282,80,9,6,74,59,132,382,325,33,113,35,381,782,38,17,13,10,16,58,73,8,5,310,122,29,86,51,16,22,30,10,16,5,58,280,43,104,79,93,15,21,400,12,49,186,333,77,206,52,4,46,39,7,457,220,66,15,35,3,150,589,8,6,7,26,2,10,143,2,46,53,176,13,27,332,182,110,116,45,84,17,400,13,26,274,17,214,5,3,83,19,191,25,121,33,7,35,52,0,3,4,17,285,11,0,10,84,3,10,1,227,2,40,137,102,37,19,11,108,28,61,160,142,71,120,131,2,190,19,42,93,52,14,2,35,393,92,23,28,268,10,401,58,9,7,5,37,2,511,540,165,66,15,66,52,11,67,5,22,29,19,87,44,2,3,38,129,55,30,99,3,701,155,6,3,19,123],"type":"bar"},{"x":["optimizing","available","guideline","experiments","classifier","accur ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4582,), (4582, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7908333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sympathy</span> <span style=''>Begins</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Smile</span> <span style='background-color:rgba(0, 255, 0, 0.7755102040816326);'>Intelligence</span> <span style=''>Begins</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Word</span> <span style=''>Use</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4074074074074073);'>Multimodal</span> <span style=''>Features</span> <span style=''>in</span> <span style=''>Spoken</span> <span style=''>Human</span> <span style=''>Robot</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Interaction</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.625531914893617);'>Recognition</span> <span style=''>of</span> <span style=''>social</span> <span style=''>signals</span> <span style=''>from</span> <span style=''>human</span> <span style=''>facial</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>expressions</span> <span style=''>or</span> <span style=''>prosody</span> <span style=''>of</span> <span style=''>speech</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>research</span> <span style=''>topic</span> <span style=''>in</span> <span style=''>human</span> <span style=''>robot</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>interaction</span> <span style=''>studies</span> <span style=''>There</span> <span style=''>is</span> <span style=''>also</span> <span style=''>a</span> <span style=''>long</span> <span style=''>line</span> <span style=''>of</span> <span style=''>research</span> <span style=''>in</span> <span style=''>the</span> <span style=''>spoken</span> <span style=''>dialogue</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>community</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>investigates</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.6470588235294117);'>satisfaction</span> <span style=''>in</span> <span style=''>relation</span> <span style=''>to</span> <span style=''>dialogue</span> <span style='background-color:rgba(0, 255, 0, 0.31428571428571417);'>characteristics</span> <span style=''>However</span> <span style=''>very</span> <span style=''>little</span> <span style=''>research</span> <span style=''>relates</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3523809523809523);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4074074074074073);'>multimodal</span> <span style=''>social</span> <span style=''>signals</span> <span style=''>and</span> <span style=''>language</span> <span style=''>features</span> <span style=''>detected</span> <span style=''>during</span> <span style=''>spoken</span> <span style=''>face</span> <span style=''>to</span> <span style=''>face</span> <span style=''>human</span> <span style=''>robot</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>interaction</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.6734693877551019);'>perception</span> <span style=''>of</span> <span style=''>a</span> <span style=''>robot</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>emotional</span> <span style=''>facial</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>expressions</span> <span style=''>of</span> <span style=''>human</span> <span style=''>users</span> <span style=''>in</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>tasks</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/><span style=''>We</span> <span style=''>suggest</span> <span style=''>a</span> <span style=''>general</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantification</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>forms</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>tasks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>It</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneous</span> <span style=''>training</span> <span style=''>of</span> <span style=''>two</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>networks</span> <span style=''>performs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>and</span> <span style=''>the</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quantifies</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>locally</span> <span style=''>averaged</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>one</span> <span style=''>Unlike</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantification</span> <span style=''>methods</span> <span style=''>the</span> <span style=''>targets</span> <span style=''>are</span> <span style=''>not</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>sampled</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>an</span> <span style=''>a</span> <span style=''>priori</span> <span style=''>given</span> <span style=''>form</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>how</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>affect</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>process</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additionally</span> <span style=''>show</span> <span style=''>that</span> <span style=''>ou ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Path</span> <span style=''>Integral</span> <span style=''>Control</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.6296296296296297);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embedding</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3443396226415095);'>stochastic</span> <span style=''>optimal</span> <span style=''>control</span> <span style=''>problems</span> <span style=''>of</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style=''>path</span> <span style=''>integral</span> <span style=''>form</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.6296296296296297);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>spaces</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>sample</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>model</span> <span style=''>free</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.48148148148148157);'>parametric</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculation</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>solution</span> <span style=''>to</span> <span style=''>the</span> <span style=''>control</span> <span style=''>problem</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>admits</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>into</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>and</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consequently</span> <span style=''>we</span> <span style=''>make</span> <span style=''>much</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>data</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>previous</span> <span style=''>sample</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>in</span> <span style=''>this</span> <span style=''>domain</span> <span style=''>eg</span> <span style=''>by</span> <span style=''>allowing</span> <span style=''>sample</span> <span style=''>re</span> <span style=''>use</span> <span style=''>across</span> <span style=''>tasks</span> <span style='background-color:rgba(255, 0, 0, 0.45112781954887216);'>Numerical</span> <span style=''>examples</span> <span style=''>on</span> <span style=''>test</span> <span style=''>problems</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3051643192488263);'>illustrate</span> <span style=''>the</span> <span style=''>sample</span> <span style='back ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kronecker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Modeling</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Dictionary</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>are</span> <span style=''>part</span> <span style=''>of</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>and</span> <span style=''>active</span> <span style=''>research</span> <span style=''>fields</span> <span style=''>at</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intersection</span> <span style=''>of</span> <span style=''>signal</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>current</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>choice</span> <span style=''>are</span> <span style=''>arguably</span> <span style=''>K</span> <span style=''>SVD</span> <span style=''>and</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>which</span> <span style=''>learn</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>(ie</span> <span style=''>a</span> <span style=''>decomposition)</span> <span style=''>for</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>via</span> <span style=''>Singular</span> <span style=''>Value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <span style=''>In</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>leading</span> <span style=''>methods</span> <span style=''>derive</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Pursuit</span> <span style=''>(PCP)</span> <span style=''>which</span> <span style=''>recovers</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>from</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corruptions</span> <span style=''>of</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnitude</span> <span style=''>and</span> <span style=''>support</span> <span style=''>However</span> <span style=''>K</span> <span style=''>SVD</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>noise</span> <span style=''>and</span> <span style=''>outliers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>training</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Additionally</span> <span style=''>PCP</span> <span style=''>does</span> <span style=''>not</ ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1263716814159292)
# 	representation (0.13911504424778762)
# 	evaluation (0.09982300884955753)
# 	segmentation (0.06867256637168141)
# 	architecture (0.09238938053097345)
# 	experimental (0.1415929203539823)
# 	detection (0.11752212389380531)
# 	information (0.24814159292035398)
# 	recognition (0.1352212389380531)
# 	convolutional (0.1415929203539823)
#
# Some Statistics words are:
# 	theoretical (0.14835443037974683)
# 	stochastic (0.14430379746835442)
# 	estimation (0.16860759493670885)
# 	statistical (0.15949367088607594)
# 	variables (0.1488607594936709)
# 	algorithm (0.39341772151898735)
# 	dimensional (0.18531645569620253)
# 	distribution (0.19139240506329114)
# 	regression (0.1888607594936709)
# 	inference (0.21265822784810126)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="545e02cd-c4a2-4274-84a7-381d33cc7d1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("545e02cd-c4a2-4274-84a7-381d33cc7d1c")) {                    Plotly.newPlot(                        "545e02cd-c4a2-4274-84a7-381d33cc7d1c",                        [{"x":["optimizing","available","guideline","experiments","classifier","accurately","therefore","separation","performance","functions","classifiers","classification","designing","different","principle","important","tensorflow","improvement","applications","technological","characteristic","similarity","processing","databases","proliferation","hausdorff","necessary","acquisition","evaluated","recognition","introduce","consequently","retrieval","descriptor","techniques","algorithm","simulations","reconstructing","compressive","preferable","accelerated","measurements","numerical","expanding","scattering","optimization","computing","guaranteed","construct","nonlinear","formation","phenomenon","measurement","inaccurate","analytically","scattered","iterative","outperforms","considerable","continuous","estimates","strategies","transforms","expectation","experimental","undirected","probabilities","distribution","structure","providing","benchmark","consistently","underlies","evaluations","combinatorial","converting","approaches","significant","construction","generality","parametric","constructions","objective","algorithms","cumulative","localizing","categorical","producing","multicenter","initiative","regression","osteoarthritis","classifying","naturally","automatic","quantification","simultaneous","detection","automatically","outperform","promising","extremely","introduces","localized","convolutional","quantifying","distinguish","including","practitioners","properties","regularly","resurgence","consistent","multilayer","traditional","applicability","challenges","highlight","anticipate","scientific","established","cheminformatics","reviewing","introductory","respective","computational","materials","transformative","expectations","particularly","chemistry","screening","disparate","prediction","documented","exponential","artificial","literature","measuring","distributional","relatedness","semantics","compositional","evaluating","empirical","combination","precision","embedding","represent","combinational","presented","outstanding","sentiment","embeddings","selecting","organized","penalizing","superiority","representation","importance","searching","beneficial","representations","attributed","efficient","minimization","disorders","dissimilar","progresses","constructing","omnipresent","framework","demonstrate","theoretical","generally","paradigms","described","discovery","continuously","perspective","mathematics","definitions","expressed","shortcomings","intelligence","possibility","interdependencies","manipulated","dependency","programming","essential","introduction","relations","characterise","information","investigate","representable","representatives","equivalence","individual","interpretations","expressivity","hypothesis","constrained","modelling","provision","candidates","mathematical","generative","formulation","compounds","structures","percentile","performing","prospective","leverages","procedure","pathology","molecular","recasting","inaccessible","subspaces","predictor","comparable","conducted","subjective","exploiting","projection","resources","predicting","baselines","supervised","describing","induction","furthermore","contextual","performances","concomitant","unbalanced","diagnosis","nucleotide","undesirable","relationships","multimodal","polymorphisms","elimination","structured","classical","multilevel","considers","combining","optimally","contributions","modalities","penalties ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	cheminformatics
# 	transformative
# 	nucleotide
# 	polymorphisms
# 	normalised
# 	economists
# 	factorize
# 	dependences
# 	confounder
# 	eigenspaces
# 	matchings
# 	overparameterized
# 	detailing
# 	chebyshev
# 	montanari
# 	cytometry
# 	ultrametric
# 	jackknife
# 	infinitesimal
# 	concavity
# Some words which never appear in Statistics papers:
# 	localizing
# 	multicenter
# 	relatedness
# 	combinational
# 	concomitant
# 	enrichment
# 	cooperative
# 	quantifiers
# 	deductive
# 	assistant
# 	capitalizes
# 	initiated
# 	deformation
# 	shiftable
# 	trigonometric
# 	shiftability
# 	grammatical
# 	linearize
# 	coreference
# 	luminance

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0458089668615986e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.75
